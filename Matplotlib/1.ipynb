# %% [markdown]
# Human mind is more addaptive to visual images than the textual format
#
# Data visualization is the graphical representation of the any data that can be more understandable.

# %% [markdown]
# there are five key plot use for the data Visulaization
#
# 1) scatter plot
#
# 2) bar graph
#
# 3) Histrogram
#
# 4) Area plot
#
# 5) pie plot

# %%
import matplotlib  
matplotlib.__version__
# Out:
# '3.7.0'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([3,4,5],[4,1,0])
plt.show()

# %%
x = [1,3,5,4,3,2,1]
y = [5,1,5,8,6,8,5]
plt.plot(x,y,"r")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot([1,2,3,4,5,6,7,8,9],'-g')  ## " -g "  this will make a green line
plt.show()

# %%
name = ["rohan","arjun","sanu"]
marks = [50,30,90]
plt.figure(figsize=(9,3))
plt.subplot(132)   ## to make 
plt.plot(name,marks)
plt.show()
plt.subplot(133)
plt.bar(name,marks)
plt.show()

# %%
import numpy as np  
import matplotlib.pyplot as plt  
  
fig = plt.figure()  
ax = plt.axes()  
  
x = np.linspace([5,3,5,4,3,2,5],stop=5)  
ax.plot(x)

# %%
import matplotlib as mpl  
from mpl_toolkits.mplot3d import Axes3D 
import numpy as np  
import matplotlib.pyplot as plt  
fig = plt.figure()  
ax = plt.axes(projection='3d')
x = [1,3,5,4,3,2,1]
y = [5,1,5,8,6,8,5]
plt.plot(x,y,"r")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
