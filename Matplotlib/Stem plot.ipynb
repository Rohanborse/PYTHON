# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6]
y = [2,2,3,4,5,6]
plt.stem(x,y,linefmt = ":",label ="python",orientation = "horizontal",use_line_collection = False)

plt.legend()
plt.show()
# Out:
# C:\Users\Rohan Borse\AppData\Local\Temp\ipykernel_3388\3930878295.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt = ":",label ="python",orientation = "horizontal",use_line_collection = False)
