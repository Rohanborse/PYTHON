# %% [markdown]
# ## Dropna

# %%
import pandas as pd

# %%
var = pd.read_csv("..\\data\\Data.csv")

# %%
var
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        NaN  1989.014944  2408.500000   2151.000000    31.250311
# 2        NaN   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000           NaN     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376           NaN     1.878165     0.596098            NaN  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...

# %%
var.dropna()
                      ## this will Drop the row that have NaN value
# Out:
#   Unnamed: 0  appeared     rank  languageRank  factCount  lastActivity  \
# 0      count    4818.0  4818.00        4303.0     4818.0        4818.0
# 6        75%    2012.0  3612.75        3226.5       29.0        2022.0
#
#    exampleCount  bookCount  paperCount  numberOfUsers  ...  packageCount  \
# 0        4818.0     4818.0      4818.0         4818.0  ...         48.00
# 6           1.0        0.0         0.0          321.0  ...      13533.75
#
#    indeedJobs.2017  subreddit.memberCount.2017  \
# 0            48.00                       40.00
# 6          6832.75                    18886.75
#
#    stackOverflowSurvey.2021.percentageUsing  stackOverflowSurvey.2021.fans  \
# 0                                    38.000                          38.00
# 6                                     0.235                       15653.25
#
#    stackOverflowSurvey.2021.medianSalary  stackOverflowSurvey.2021.users  \
# 0                                   38.0                           38.00
# ...

# %%
var.dropna(axis=1)            ## this will Drop the coloumn that have NaN value   
                              ##   beacause we use axis = 1 it is working along the coloumn
# Out:
#       appeared         rank    factCount    bookCount  \
# 0  4818.000000  4818.000000  4818.000000  4818.000000
# 1  1989.014944  2408.500000    31.250311     1.878165
# 2   147.682103  1390.981129    52.797709    16.404652
# 3 -2700.000000     0.000000     3.000000     0.000000
# 4  1985.000000  1204.250000     8.000000     0.000000
# 5  1998.000000  2408.500000    15.000000     0.000000
# 6  2012.000000  3612.750000    29.000000     0.000000
# 7  2023.000000  4817.000000   920.000000   401.000000
#
#    centralPackageRepositoryCount  wikipedia.backlinksCount  \
# 0                           3024               1625.000000
# 1                              0                371.035692
# 2                              0               1760.943321
# 3                              0                  1.000000
# 4                              0                 15.000000
# 5                              0                 48.000000
# 6                              0                158.000000
# ...

# %%
var.dropna(how="all")                 ## if total row have value NaN that row will only remove
var.dropna(how="any")                 ## if any NaN value is present then total row will be remove
# Out:
#   Unnamed: 0  appeared     rank  languageRank  factCount  lastActivity  \
# 0      count    4818.0  4818.00        4303.0     4818.0        4818.0
# 6        75%    2012.0  3612.75        3226.5       29.0        2022.0
#
#    exampleCount  bookCount  paperCount  numberOfUsers  ...  packageCount  \
# 0        4818.0     4818.0      4818.0         4818.0  ...         48.00
# 6           1.0        0.0         0.0          321.0  ...      13533.75
#
#    indeedJobs.2017  subreddit.memberCount.2017  \
# 0            48.00                       40.00
# 6          6832.75                    18886.75
#
#    stackOverflowSurvey.2021.percentageUsing  stackOverflowSurvey.2021.fans  \
# 0                                    38.000                          38.00
# 6                                     0.235                       15653.25
#
#    stackOverflowSurvey.2021.medianSalary  stackOverflowSurvey.2021.users  \
# 0                                   38.0                           38.00
# ...

# %%
var.dropna(subset=["paperCount"])  ## this will search for the coloum paperCount and in that coloum 
                                   ## if there is NaN value is present then that coloumn will be Remove
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        NaN  1989.014944  2408.500000   2151.000000    31.250311
# 2        NaN   147.682103  1390.981129   1242.313433    52.797709
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376           NaN     1.878165     0.596098            NaN  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# 5           NaN      0.000000     0.000000     0.000000   2.900000e+01  ...
# 6   2022.000000      1.000000     0.000000     0.000000   3.210000e+02  ...
# ...

# %%
##var.dropna(inplace=True)
##var

# %%
var.dropna(thresh = 1) 
var
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        NaN  1989.014944  2408.500000   2151.000000    31.250311
# 2        NaN   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000           NaN     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376           NaN     1.878165     0.596098            NaN  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...
