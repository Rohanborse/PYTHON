# %% [markdown]
# nrows=1 :- to select the perticular Row
#
#
# usecols=["Title"] :- this will show the perticular coloum name title . we can access the multiple coloum in "usecols"
#
#                     by using  usecols = ["title","bookCount"] ,By this we can access the two coloum name title and                             bookCount
#
#                     we can also use the index no. of the coloum to get the coloum
#
#
# skiprows= [0,3,6,5] :- skiprows function will skip the rows provided in that function
#
# index_col = "appeared" :- This will make the "appeared" coloum as a index coloum.
#
# header = 1 :- this will make the number one row as header.  1 is row no.
#
# names = ["col1","col2"] :- this will give the name to coloum from the end
#
# header = None :- this will change the header by the no.  1,2,3,........n
#
# prifix = "Coloum"  :- if we use header none then we use prefix then it will appear like  Coloum1,Coloum2,......Coloum n
#
#                         Argument prefix must be None if argument header is not None
#
# dtype={"factCount":"float"}  :- this will chang the datatype of the given coloum in ths ew have to pass the data
#
#                                  in the key value pair means in dictionary format2

# %%
import pandas as pd

csv_1 = pd.read_csv("data\\pldb.csv")

csv_1
# Out:
# C:\Users\Rohan Borse\AppData\Local\Temp\ipykernel_20580\2751024486.py:3: DtypeWarning: Columns (15,16,17,25,30,38,41,44,46,47,48,49,50,51,52,53,56,59,60,61,63,69,71,72,73,75,76,78,79,80,81,82,83,84,85,87,89,91,92,93,94,95,96,97,98,99,100,101,103,104,110,111,112,113,114,115,116,117,119,121,122,123,126,128,129,130,131,132,133,134,135,137,138,142,143,144,145,146,147,148,150,151,156,157,158,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,183,184,185,186,187,188,189,190,191,192,194,195,196,197,198,200,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,
# ...

# %%
csv_2 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",nrows=6)
csv_2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 csv_2 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",nrows=6)
#       2 csv_2
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
csv_3 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",usecols=["title"])
csv_3

# %%
csv_4 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",usecols=[0,3,6])
csv_4                    ## by using the index no

# %%
csv_5 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",skiprows = [0,2,3,6])
csv_5

# %%
csv_6 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",index_col= "appeared")
csv_6

# %%
csv_7 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",header = 1)
csv_7

# %%
csv_8 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",names = ["col1","col2"])
csv_8

# %%
csv_9 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",header = None,prefix ="Coloum")
csv_9

# %%
csv1 = pd.read_csv("C:\\Users\\Rohan Borse\\Desktop\\RB Python Practice\\Pandas\\pldb.csv",dtype={"factCount":"float"})
csv1
