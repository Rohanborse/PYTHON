# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,8]
y = [3,10]
plt.plot([1,8,3,10],color= "orange",marker= "*",mec ="r",linewidth = "5")
plt.ylabel("Y-Axis")            ## label to y axis
plt.xlabel("X-Axis")           ## label to x axis
plt.title("Test")
plt.grid()
plt.show()
