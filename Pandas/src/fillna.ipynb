# %% [markdown]
# # fillna()

# %%
import pandas as pd

# %%
var = pd.read_csv("..\\data\\Data.csv")
var
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        NaN  1989.014944  2408.500000   2151.000000    31.250311
# 2        NaN   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000           NaN     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376           NaN     1.878165     0.596098            NaN  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...

# %%
var.fillna("python")         ## this function fill the NaN value by the  String we pass
# Out:
#   Unnamed: 0     appeared         rank languageRank    factCount lastActivity  \
# 0      count  4818.000000  4818.000000       4303.0  4818.000000       4818.0
# 1     python  1989.014944  2408.500000       2151.0    31.250311  1998.455376
# 2     python   147.682103  1390.981129  1242.313433    52.797709   131.016472
# 3        min -2700.000000     0.000000          0.0     3.000000      -2700.0
# 4        25%  1985.000000  1204.250000       python     8.000000       1993.0
# 5        50%  1998.000000  2408.500000       2151.0    15.000000       python
# 6        75%  2012.000000  3612.750000       3226.5    29.000000       2022.0
# 7        max  2023.000000  4817.000000       4302.0   920.000000       2023.0
#
#   exampleCount    bookCount paperCount numberOfUsers  ...  packageCount  \
# 0       4818.0  4818.000000     4818.0        4818.0  ...  4.800000e+01
# 1       python     1.878165   0.596098        python  ...  5.054317e+04
# ...

# %%
var.fillna({"languageRank" : "java","paperCount" : "C++","exampleCount" : "mongoDB"})

## by this we can replace the NaN value in the Specific Coloum
# Out:
#   Unnamed: 0     appeared         rank languageRank    factCount  \
# 0      count  4818.000000  4818.000000       4303.0  4818.000000
# 1        NaN  1989.014944  2408.500000       2151.0    31.250311
# 2        NaN   147.682103  1390.981129  1242.313433    52.797709
# 3        min -2700.000000     0.000000          0.0     3.000000
# 4        25%  1985.000000  1204.250000         java     8.000000
# 5        50%  1998.000000  2408.500000       2151.0    15.000000
# 6        75%  2012.000000  3612.750000       3226.5    29.000000
# 7        max  2023.000000  4817.000000       4302.0   920.000000
#
#    lastActivity exampleCount    bookCount paperCount  numberOfUsers  ...  \
# 0   4818.000000       4818.0  4818.000000     4818.0   4.818000e+03  ...
# 1   1998.455376      mongoDB     1.878165   0.596098            NaN  ...
# 2    131.016472     3.261637    16.404652   3.576037   2.231984e+05  ...
# 3  -2700.000000          0.0     0.000000        C++   0.000000e+00  ...
# ...

# %%
var.fillna(method = "bfill")   
## by this we can fill the NaN Data by the forword fill {ffill} or by Backward Fill {bfill}
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        min  1989.014944  2408.500000   2151.000000    31.250311
# 2        min   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000   2151.000000     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376      3.261637     1.878165     0.596098   2.231984e+05  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...

# %%
var.fillna(method = "bfill",axis=1)
# Out:
#     Unnamed: 0     appeared         rank languageRank  factCount lastActivity  \
# 0        count       4818.0       4818.0       4303.0     4818.0       4818.0
# 1  1989.014944  1989.014944       2408.5       2151.0  31.250311  1998.455376
# 2   147.682103   147.682103  1390.981129  1242.313433  52.797709   131.016472
# 3          min      -2700.0          0.0          0.0        3.0      -2700.0
# 4          25%       1985.0      1204.25          8.0        8.0       1993.0
# 5          50%       1998.0       2408.5       2151.0       15.0          0.0
# 6          75%       2012.0      3612.75       3226.5       29.0       2022.0
# 7          max       2023.0       4817.0       4302.0      920.0       2023.0
#
#   exampleCount  bookCount paperCount numberOfUsers  ... packageCount  \
# 0       4818.0     4818.0     4818.0        4818.0  ...         48.0
# 1     1.878165   1.878165   0.596098    399.992528  ...  50543.16667
# ...

# %%
var.fillna(method = "bfill",inplace = True)
var
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        min  1989.014944  2408.500000   2151.000000    31.250311
# 2        min   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000   2151.000000     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376      3.261637     1.878165     0.596098   2.231984e+05  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...

# %%
var1 = pd.read_csv("..\\data\\Data.csv")
var1
# Out:
#   Unnamed: 0     appeared         rank  languageRank    factCount  \
# 0      count  4818.000000  4818.000000   4303.000000  4818.000000
# 1        NaN  1989.014944  2408.500000   2151.000000    31.250311
# 2        NaN   147.682103  1390.981129   1242.313433    52.797709
# 3        min -2700.000000     0.000000      0.000000     3.000000
# 4        25%  1985.000000  1204.250000           NaN     8.000000
# 5        50%  1998.000000  2408.500000   2151.000000    15.000000
# 6        75%  2012.000000  3612.750000   3226.500000    29.000000
# 7        max  2023.000000  4817.000000   4302.000000   920.000000
#
#    lastActivity  exampleCount    bookCount   paperCount  numberOfUsers  ...  \
# 0   4818.000000   4818.000000  4818.000000  4818.000000   4.818000e+03  ...
# 1   1998.455376           NaN     1.878165     0.596098            NaN  ...
# 2    131.016472      3.261637    16.404652     3.576037   2.231984e+05  ...
# ...

# %%
var1.fillna("python",limit = 1)       
                    ## this Work for the coloumn if 
                    ## one coloum have many NaN then
                    ##it will fill As per the Set limit
# Out:
#   Unnamed: 0     appeared         rank languageRank    factCount lastActivity  \
# 0      count  4818.000000  4818.000000       4303.0  4818.000000       4818.0
# 1     python  1989.014944  2408.500000       2151.0    31.250311  1998.455376
# 2        NaN   147.682103  1390.981129  1242.313433    52.797709   131.016472
# 3        min -2700.000000     0.000000          0.0     3.000000      -2700.0
# 4        25%  1985.000000  1204.250000       python     8.000000       1993.0
# 5        50%  1998.000000  2408.500000       2151.0    15.000000       python
# 6        75%  2012.000000  3612.750000       3226.5    29.000000       2022.0
# 7        max  2023.000000  4817.000000       4302.0   920.000000       2023.0
#
#   exampleCount    bookCount paperCount numberOfUsers  ...  packageCount  \
# 0       4818.0  4818.000000     4818.0        4818.0  ...  4.800000e+01
# 1       python     1.878165   0.596098        python  ...  5.054317e+04
# ...

# %%
dumi_df.fillna(dumi_df.mean(numeric_only = True).round(1),inplace = True)

## fill NAN value  by mean of each column
